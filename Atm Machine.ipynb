# %%
cardstatus=str(input("Do you Have Card?" )).lower()
if cardstatus=='yes':
    pin=int(input("Enter Your Pin "))
    username=str(input("Enter Your Username ")).lower()
    if pin==1234 and username=='qaisar12':
        
        print("hello !",username)
               
        balance=1500000
        print("    ATM    ")
        print("""
        1)        Balance
        2)        Withdraw
        3)        Deposit
        4)        Quit


        """)
        
        Option=int(input("Enter Option: "))
    

        if Option==1:
            print("Balance  Rs ",balance)


        if Option==2:
            print("Balance  Rs",balance)
            withdraw=float(input("Enter Withdraw amount Rs"))
            if withdraw>0.00 and withdraw<=balance:
                forwardbalance=(balance-withdraw)
                print("your New Balance in Rs ",forwardbalance)
            elif withdraw>balance:
                print("You Cant Play With Computer :)")
            else:
                print("None withdraw made")

        if Option==3:
            print("Balance Rs",balance)
            Deposit=float(input("Enter deposit amount Rs "))
            if Deposit>0:
                forwardbalance=(balance+Deposit)
                print("your New Balance in Rs" ,forwardbalance)
            else:
                print("None deposit made")


        if Option==4:
            exit()
    elif pin==1357 and username=='hassann':
        
        print("hello !",username)
        balance=30000000
        print("    ATM    ")
        print("""
        1)        Balance
        2)        Withdraw
        3)        Deposit
        4)        Quit


        """)
        
        Option=int(input("Enter Option: "))
    

        if Option==1:
            print("Balance  Rs ",balance)


        if Option==2:
            print("Balance  Rs",balance)
            withdraw=float(input("Enter Withdraw amount Rs"))
            if withdraw>0.00 and withdraw<=balance:
                forwardbalance=(balance-withdraw)
                print("your New Balance in Rs ",forwardbalance)
            elif withdraw>balance:
                print("You Cant Play With Computer :)")
            else:
                print("None withdraw made")

        if Option==3:
            print("Balance Rs",balance)
            Deposit=float(input("Enter deposit amount Rs "))
            if Deposit>0:
                forwardbalance=(balance+Deposit)
                print("your New Balance in Rs" ,forwardbalance)
            else:
                print("None deposit made")


        if Option==4:
            exit()
    elif pin==2345 and username=='obaidi':
        
        print("hello !",username)
        balance=5000000
        print("    ATM    ")
        print("""
        1)        Balance
        2)        Withdraw
        3)        Deposit
        4)        Quit


        """)
        
        Option=int(input("Enter Option: "))
    

        if Option==1:
            print("Balance  Rs ",balance)


        if Option==2:
            print("Balance  Rs",balance)
            withdraw=float(input("Enter Withdraw amount Rs"))
            if withdraw>0.00 and withdraw<=balance:
                forwardbalance=(balance-withdraw)
                print("your New Balance in Rs ",forwardbalance)
            elif withdraw>balance:
                print("You Cant Play With Computer :)")
            else:
                print("None withdraw made")

        if Option==3:
            print("Balance Rs",balance)
            Deposit=float(input("Enter deposit amount Rs "))
            if Deposit>0:
                forwardbalance=(balance+Deposit)
                print("your New Balance in Rs" ,forwardbalance)
            else:
                print("None deposit made")


        if Option==4:
            exit()
    elif pin==6789 and username=='maaz20':
        
        print("hello !",username)
        balance=700000
        print("    ATM    ")
        print("""
        1)        Balance
        2)        Withdraw
        3)        Deposit
        4)        Quit


        """)
        
        Option=int(input("Enter Option: "))
    

        if Option==1:
            print("Balance  Rs ",balance)


        if Option==2:
            print("Balance  Rs",balance)
            withdraw=float(input("Enter Withdraw amount Rs"))
            if withdraw>0.00 and withdraw<=balance:
                forwardbalance=(balance-withdraw)
                print("your New Balance in Rs ",forwardbalance)
            elif withdraw>balance:
                print("You Cant Play With Computer :)")
            else:
                print("None withdraw made")

        if Option==3:
            print("Balance Rs",balance)
            Deposit=float(input("Enter deposit amount Rs "))
            if Deposit>0:
                forwardbalance=(balance+Deposit)
                print("your New Balance in Rs" ,forwardbalance)
            else:
                print("None deposit made")


        if Option==4:
            exit()
    elif pin==1896 and username=='wali25':
        
        print("hello !",username)
        balance=990000
        print("    ATM    ")
        print("""
        1)        Balance
        2)        Withdraw
        3)        Deposit
        4)        Quit


        """)
        
        Option=int(input("Enter Option: "))
    

        if Option==1:
            print("Balance  Rs ",balance)


        if Option==2:
            print("Balance  Rs",balance)
            withdraw=float(input("Enter Withdraw amount Rs"))
            if withdraw>0.00 and withdraw<=balance:
                forwardbalance=(balance-withdraw)
                print("your New Balance in Rs ",forwardbalance)
            elif withdraw>balance:
                print("You Cant Play With Computer :)")
            else:
                print("None withdraw made")

        if Option==3:
            print("Balance Rs",balance)
            Deposit=float(input("Enter deposit amount Rs "))
            if Deposit>0:
                forwardbalance=(balance+Deposit)
                print("your New Balance in Rs" ,forwardbalance)
            else:
                print("None deposit made")


        if Option==4:
            exit()
    elif pin==1567 and username=='bilal19':
        
        print("hello !",username)
        balance=6780000
        print("    ATM    ")
        print("""
        1)        Balance
        2)        Withdraw
        3)        Deposit
        4)        Quit


        """)
        
        Option=int(input("Enter Option: "))
    

        if Option==1:
            print("Balance  Rs ",balance)


        if Option==2:
            print("Balance  Rs",balance)
            withdraw=float(input("Enter Withdraw amount Rs"))
            if withdraw>0.00 and withdraw<=balance:
                forwardbalance=(balance-withdraw)
                print("your New Balance in Rs ",forwardbalance)
            elif withdraw>balance:
                print("You Cant Play With Computer :)")
            else:
                print("None withdraw made")

        if Option==3:
            print("Balance Rs",balance)
            Deposit=float(input("Enter deposit amount Rs "))
            if Deposit>0:
                forwardbalance=(balance+Deposit)
                print("your New Balance in Rs" ,forwardbalance)
            else:
                print("None deposit made")


        if Option==4:
            exit()
    elif pin==1526 and username=='waseem50':
        
        print("hello !",username)
        balance=10000000
        print("    ATM    ")
        print("""
        1)        Balance
        2)        Withdraw
        3)        Deposit
        4)        Quit


        """)
        
        Option=int(input("Enter Option: "))
    

        if Option==1:
            print("Balance  Rs ",balance)


        if Option==2:
            print("Balance  Rs",balance)
            withdraw=float(input("Enter Withdraw amount Rs"))
            if withdraw>0.00 and withdraw<=balance:
                forwardbalance=(balance-withdraw)
                print("your New Balance in Rs ",forwardbalance)
            elif withdraw>balance:
                print("You Cant Play With Computer :)")
            else:
                print("None withdraw made")

        if Option==3:
            print("Balance Rs",balance)
            Deposit=float(input("Enter deposit amount Rs "))
            if Deposit>0:
                forwardbalance=(balance+Deposit)
                print("your New Balance in Rs" ,forwardbalance)
            else:
                print("None deposit made")


        if Option==4:
            exit()
    elif pin==3412 and username=='faizan23':
        
        print("hello !",username)
        balance=120000
        print("    ATM    ")
        print("""
        1)        Balance
        2)        Withdraw
        3)        Deposit
        4)        Quit


        """)
        
        Option=int(input("Enter Option: "))
    

        if Option==1:
            print("Balance  Rs ",balance)


        if Option==2:
            print("Balance  Rs",balance)
            withdraw=float(input("Enter Withdraw amount Rs"))
            if withdraw>0.00 and withdraw<=balance:
                forwardbalance=(balance-withdraw)
                print("your New Balance in Rs ",forwardbalance)
            elif withdraw>balance:
                print("You Cant Play With Computer :)")
            else:
                print("None withdraw made")

        if Option==3:
            print("Balance Rs",balance)
            Deposit=float(input("Enter deposit amount Rs "))
            if Deposit>0:
                forwardbalance=(balance+Deposit)
                print("your New Balance in Rs" ,forwardbalance)
            else:
                print("None deposit made")


        if Option==4:
            exit()
    elif pin==8291 and username=='junaid20' :
        
        print("hello !",username)
        balance=1339590000
        print("    ATM    ")
        print("""
        1)        Balance
        2)        Withdraw
        3)        Deposit
        4)        Quit


        """)
        
        Option=int(input("Enter Option: "))
    

        if Option==1:
            print("Balance  Rs ",balance)


        if Option==2:
            print("Balance  Rs",balance)
            withdraw=float(input("Enter Withdraw amount Rs"))
            if withdraw>0.00 and withdraw<=balance:
                forwardbalance=(balance-withdraw)
                print("your New Balance in Rs ",forwardbalance)
            elif withdraw>balance:
                print("You Cant Play With Computer :)")
            else:
                print("None withdraw made")

        if Option==3:
            print("Balance Rs",balance)
            Deposit=float(input("Enter deposit amount Rs "))
            if Deposit>0:
                forwardbalance=(balance+Deposit)
                print("your New Balance in Rs" ,forwardbalance)
            else:
                print("None deposit made")


        if Option==4:
            exit()
    elif pin==1166 and username=='hammad16':
        
        print("hello !",username)
        balance=1650000
        print("    ATM    ")
        print("""
        1)        Balance
        2)        Withdraw
        3)        Deposit
        4)        Quit


        """)
        
        Option=int(input("Enter Option: "))
    

        if Option==1:
            print("Balance  Rs ",balance)


        if Option==2:
            print("Balance  Rs",balance)
            withdraw=float(input("Enter Withdraw amount Rs"))
            if withdraw>0.00 and withdraw<=balance:
                forwardbalance=(balance-withdraw)
                print("your New Balance in Rs ",forwardbalance)
            elif withdraw>balance:
                print("You Cant Play With Computer :)")
            else:
                print("None withdraw made")

        if Option==3:
            print("Balance Rs",balance)
            Deposit=float(input("Enter deposit amount Rs "))
            if Deposit>0:
                forwardbalance=(balance+Deposit)
                print("your New Balance in Rs" ,forwardbalance)
            else:
                print("None deposit made")


        if Option==4:
            exit()
    elif pin==1765 and username=='jamshed18':
        
        print("hello !",username)
        balance=900000
        print("    ATM    ")
        print("""
        1)        Balance
        2)        Withdraw
        3)        Deposit
        4)        Quit


        """)
        
        Option=int(input("Enter Option: "))
    

        if Option==1:
            print("Balance  Rs ",balance)


        if Option==2:
            print("Balance  Rs",balance)
            withdraw=float(input("Enter Withdraw amount Rs"))
            if withdraw>0.00 and withdraw<=balance:
                forwardbalance=(balance-withdraw)
                print("your New Balance in Rs ",forwardbalance)
            elif withdraw>balance:
                print("You Cant Play With Computer :)")
            else:
                print("None withdraw made")

        if Option==3:
            print("Balance Rs",balance)
            Deposit=float(input("Enter deposit amount Rs "))
            if Deposit>0:
                forwardbalance=(balance+Deposit)
                print("your New Balance in Rs" ,forwardbalance)
            else:
                print("None deposit made")


        if Option==4:
            exit()
    elif pin==5412 and username=='uzairahmed18':
        
        print("hello !",username)
        balance=4000000
        print("    ATM    ")
        print("""
        1)        Balance
        2)        Withdraw
        3)        Deposit
        4)        Quit


        """)
        
        Option=int(input("Enter Option: "))
    

        if Option==1:
            print("Balance  Rs ",balance)


        if Option==2:
            print("Balance  Rs",balance)
            withdraw=float(input("Enter Withdraw amount Rs"))
            if withdraw>0.00 and withdraw<=balance:
                forwardbalance=(balance-withdraw)
                print("your New Balance in Rs ",forwardbalance)
            elif withdraw>balance:
                print("You Cant Play With Computer :)")
            else:
                print("None withdraw made")

        if Option==3:
            print("Balance Rs",balance)
            Deposit=float(input("Enter deposit amount Rs "))
            if Deposit>0:
                forwardbalance=(balance+Deposit)
                print("your New Balance in Rs" ,forwardbalance)
            else:
                print("None deposit made")


        if Option==4:
            exit()
    else:
        print("You Entered Wrong Pin")
else:
    print("You May Bring Your Card Sorry Sir")
# Out:
# Do you Have Card?yes
# Enter Your Pin 5412
# Enter Your Username uzairahmed18
# hello ! uzairahmed18
#     ATM
#
#         1)        Balance
#         2)        Withdraw
#         3)        Deposit
#         4)        Quit
#
#
#
# Enter Option: 2
# Balance  Rs 4000000

# %%
THese Are The Usernames and Pins 
6789 maaz20
1357 hassann
1234 qaisar12
2345 obaidi
1896 wali25
1567 bilal19
1526 waseem50
3412 faizan23
8291 junaid20
1166 hammad16
1765 jamshed18
5412 uzairahmed18
# Out:
#   File "<ipython-input-5-4990739114eb>", line 1
#     THese Are The Usernames and Pins
#             ^
# SyntaxError: invalid syntax
